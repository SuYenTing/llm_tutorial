# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
import time
import random

# %%
# MOPS搜尋頁面
url = "https://mops.twse.com.tw/mops/api/t05st02"

payload = {
    "year":"104",
    "month":"11",
    "day":"23"
}

headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/json",
}

# 發送 POST 請求
response = requests.post(url, json=payload, headers=headers)

print("Status Code:", response.status_code)

# 解析 JSON（若回傳為 JSON）
try:
    data = response.json()
    print("Response JSON:")
    pprint(data)
except Exception:
    print("Response Text:")
    print(response.text)
# Out:
# Status Code: 200
# Response JSON:
# {'code': 200,
#  'datetime': '114/11/23 10:47:23',
#  'message': '查詢成功',
#  'result': {'data': [['104/11/23',
#                       '08:36:08',
#                       '9802',
#                       '鈺齊-KY',
#                       '公告本公司受邀參加麥格理證&#21173;、台灣證&#21173;交易所及證券櫃檯買賣中心合辦之「Taiwan '
#                       'corporate day」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '9802',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '08:59:02',
#                       '1339',
#                       '昭輝',
#                       '公告本公司第一次買回庫藏股期間屆滿及執行狀況',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1339',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '09:03:19',
#                       '2345',
#                       '智邦',
#                       '澄清 11/23 自由時報對本公司之報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2345',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '09:09:24',
#                       '3003',
#                       '健和興',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3003',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '09:49:53',
#                       '9910',
#                       '豐泰',
#                       '本公司受邀參加麥格理證券舉辦之「North Asia Corporate Day」視訊會議',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '9910',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:00:08',
#                       '2313',
#                       '華通',
#                       '說明11/21蘋果日報',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2313',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:19:46',
#                       '8478',
#                       '東哥遊艇',
#                       '本公司於104年11月24日至104年11月27日受邀參加麥格理證券舉辦之2015 Macquarie '
#                       'Taiwan Corporate Day',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8478',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:36:37',
#                       '3090',
#                       '日電貿',
#                       '澄清有關工商時報B3版對本公司之報導內容。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3090',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:48:40',
#                       '4736',
#                       '泰博',
#                       '本公司澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4736',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:16:25',
#                       '1536',
#                       '和大',
#                       '說明有關104/11/23經濟日報之報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1536',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:22:35',
#                       '2002',
#                       '中鋼',
#                       '104.11.23 經濟日報第C5版報導說明',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2002',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:32:15',
#                       '1904',
#                       '正隆',
#                       '澄清104/11/23蘋果日報之報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1904',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:43:17',
#                       '2614',
#                       '東森',
#                       '說明媒體報導東森電視股權交易事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2614',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:48:20',
#                       '2501',
#                       '國建',
#                       '澄清工商時報104年11月23日有關本公司營收之報導。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2501',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:58:47',
#                       '6456',
#                       'GIS-KY',
#                       '公告本公司收回已發行之限制員工權利新股辦理註銷完成公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6456',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '13:30:26',
#                       '2108',
#                       '南帝',
#                       '董事會決議召開105年第一次股東臨時會。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2108',
#                                       'enterDate': '1041120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '13:50:57',
#                       '6456',
#                       'GIS-KY',
#                       '公告本公司將參加麥格理證券所舉辦之『Taiwan Corporate Days』',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6456',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '13:56:46',
#                       '9917',
#                       '中保科',
#                       '公告更正本公司104年度第三季合併財務報告第63頁',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '9917',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '14:11:39',
#                       '4958',
#                       '臻鼎-KY',
#                       '代子公司富葵精密組件(深圳)有限公司公告處分理財產品',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4958',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '14:15:21',
#                       '4958',
#                       '臻鼎-KY',
#                       '代子公司富葵精密組件（深圳）有限公司公告取得理財產品',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4958',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '14:18:08',
#                       '6184',
#                       '大豐電',
#                       '代子公司台灣數位寬頻有線電視(股)公司公告總經理異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6184',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '14:18:54',
#                       '6184',
#                       '大豐電',
#                       '代子公司台灣數位寬頻有線電視(股)公司公告董事會解除\r\n經理人競業禁止之限制',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6184',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '14:52:44',
#                       '1216',
#                       '統一',
#                       '本公司應麥格里證券之邀於104/11/24~25在台北以視訊方式參加法說會，報告本公司截至104年前三季度營運與財務概況',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1216',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '14:55:36',
#                       '2338',
#                       '光罩',
#                       '本公司董會決議辦理註銷庫藏股\r\n並訂定減資基準日',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2338',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '14:59:22',
#                       '4912',
#                       '聯德控股-KY',
#                       '澄清104年11月20日鉅亨網之報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4912',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:00:13',
#                       '1589',
#                       '永冠-KY',
#                       '公告本公司受邀參加麥格理證券舉辦之『Macquarie North Asia Corp Day』',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1589',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:10:10',
#                       '3701',
#                       '大眾控',
#                       '代子公司BROAD CORPORATION公告背書保證相關資料',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3701',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:15:39',
#                       '4438',
#                       '廣越',
#                       '本公司11/24~11/26受麥格理證券邀請參加『Taiwan Corporate Days』',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4438',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:35:21',
#                       '4557',
#                       '永新-KY',
#                       '本公司受邀參加台灣證券交易所舉辦之法說會。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4557',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:47:11',
#                       '2449',
#                       '京元電子',
#                       '本公司庫藏股註銷實收資本額變更登記事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2449',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:56:11',
#                       '2231',
#                       '為升',
#                       '公告本公司董事會決議召開一○五年第一次股東臨時會事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2231',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:03:59',
#                       '1440',
#                       '南紡',
#                       '公告本公司應邀參加麥格理證券舉辦之海外法人說明會。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1440',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:35:07',
#                       '2330',
#                       '台積電',
#                       '本公司訂購廠務設備或工程公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2330',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:45:12',
#                       '2867',
#                       '三商壽',
#                       '本公司參加麥格理證券舉辦之新加坡、香港法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2867',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:47:00',
#                       '4108',
#                       '懷特',
#                       '係因本公司有價證券於集中交易市場達公佈注意交易資訊標準\r\n'
#                       '，故公佈相關財務業務等重大訊息，以利投資人區別瞭解。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4108',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:50:31',
#                       '2231',
#                       '為升',
#                       '本公司受邀參加元富證券於馬來西亞吉隆坡及新加坡舉辦之投資論壇',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2231',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '16:58:23',
#                       '2881',
#                       '富邦金',
#                       '富邦金控代子公司富邦金控創業投資公告贊助富邦文教基金\r\n會，總計375,000美元整。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2881',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:01:50',
#                       '3703',
#                       '欣陸',
#                       '代子公司欣達環工股份有限公司\r\n依公開發行公司資金貸與及背書保證處理準則\r\n第25條第一項四款規定公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3703',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:03:40',
#                       '2892',
#                       '第一金',
#                       '代子公司第一金人壽保險股份有限公司\r\n公告法人股東(英商英傑華國際控股有限公司)董事代表人改派事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2892',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:07:18',
#                       '1721',
#                       '三晃',
#                       '修正公告本公司董事會決議通過與國慶化學股份有限公司合併案。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1721',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:08:38',
#                       '2308',
#                       '台達電',
#                       '公告本公司104年7、8月份關係人交易-取得資產自結數金額更新',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2308',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:14:28',
#                       '1721',
#                       '三晃',
#                       '修正本公司董事會決議通過與國慶化學(股)公司合併案，擬\r\n發行新股。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1721',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:16:13',
#                       '2880',
#                       '華南金',
#                       '代子公司華南銀行公告臨時董事會通過辦理105年度應分攤\r\n捐助財團法人中小企業信用保證基金款項',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2880',
#                                       'enterDate': '1041120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:17:11',
#                       '4164',
#                       '承業醫',
#                       '本公司於2015/11/24召開法人說明會之相關資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4164',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:20:11',
#                       '2880',
#                       '華南金',
#                       '本公司董事會通過指派子公司華南永昌證券投資信託股份\r\n有限公司第9屆董事及監察人',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2880',
#                                       'enterDate': '1041120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:20:30',
#                       '1321',
#                       '大洋',
#                       '代子公司公告:伸洋開發股份有限公司發行新股案。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1321',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '17:39:45',
#                       '8016',
#                       '矽創',
#                       '本公司受邀參加Maquarie Corporate Day論壇活動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8016',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:40:23',
#                       '8016',
#                       '矽創',
#                       '本公司受邀參加2016日盛投資展望說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8016',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:52:33',
#                       '2317',
#                       '鴻海',
#                       '補充說明本公司於104年9月15日公告董事會決議發行\r\n無擔保普通公司債',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2317',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:53:52',
#                       '2317',
#                       '鴻海',
#                       '代子公司富智康精密組件(北京)有限公司公告處分理財產品',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2317',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:54:10',
#                       '2317',
#                       '鴻海',
#                       '代子公司富智康精密組件(北京)有限公司公告取得理財產品',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2317',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '17:55:52',
#                       '6197',
#                       '佳必琪',
#                       '公告本公司召開法說會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6197',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:56:13',
#                       '4976',
#                       '佳凌',
#                       '本公司收回已發行之限制員工權利新股辦理註銷完成公告。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4976',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:58:31',
#                       '1795',
#                       '美時',
#                       '本公司受邀參加富邦證券舉辦之法人座談會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1795',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '18:00:59',
#                       '5306',
#                       '桂盟',
#                       '本公司受邀參加櫃檯買賣中心與麥格里證券舉辦之「Taiwan Corporate Day」活動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5306',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '18:18:18',
#                       '2882',
#                       '國泰金',
#                       '本公司代子公司國泰人壽公告取得不動產',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2882',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '18:44:27',
#                       '2467',
#                       '志聖',
#                       '公告本公司總經理異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2467',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '18:46:30',
#                       '2467',
#                       '志聖',
#                       '公告本公司研發主管異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2467',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '19:19:48',
#                       '9933',
#                       '中鼎',
#                       '阿曼煉油及石油工業公司80萬噸蒸汽裂解裝置設備統包工程\r\n'
#                       '案，本公司與芝加哥橋樑及鋼鐵公司共同聯盟投標，現已取得業\r\n'
#                       '主得標通知函。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '9933',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 5}}],
#                      ['104/11/23',
#                       '19:21:15',
#                       '2883',
#                       '凱基金',
#                       '中華開發金控董事會決議買回股份減資事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2883',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '19:21:33',
#                       '2883',
#                       '凱基金',
#                       '中華開發金控代子公司凱基銀行公告董事變動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2883',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '19:21:49',
#                       '2883',
#                       '凱基金',
#                       'CDIB Global Markets I Limited、CDIB Global Markets\r\n'
#                       'II Limited及CDIB Global Markets III Limited\r\n'
#                       '公告三家公司進行合併',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2883',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '19:22:06',
#                       '2883',
#                       '凱基金',
#                       '中華開發金控代子公司開發工銀所屬之CDIB Global Markets\r\n'
#                       'II Limited公告股東會重要決議事項',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2883',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 4}}],
#                      ['104/11/23',
#                       '20:21:52',
#                       '5880',
#                       '合庫金',
#                       '代子公司合作金庫商業銀行公告內部稽核主管異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5880',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '20:22:17',
#                       '5880',
#                       '合庫金',
#                       '代子公司合作金庫創業投資股份有限公司公告董事異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5880',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '20:22:33',
#                       '5880',
#                       '合庫金',
#                       '代子公司合作金庫商業銀行股份有限公司公告董事會決議\r\n編列預算於大台北地區及大陸地區購置自有行舍',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5880',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '23:58:07',
#                       '8478',
#                       '東哥遊艇',
#                       '補充公告東哥遊艇董事會決議召開104年股東臨時會公告\r\n(增列議案)',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8478',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '08:09:55',
#                       '3265',
#                       '台星科',
#                       '公告台灣星科金朋半導體股份有限公司\r\n更名為台星科股份有限公司',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3265',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '08:29:38',
#                       '6114',
#                       '久威',
#                       '公告本公司名稱由「翔昇電子股份有限公司」更名為\r\n「久威國際股份有限公司」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6114',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '08:49:33',
#                       '6279',
#                       '胡連',
#                       '本公司受邀參加櫃買中心與麥格理資本證券合辦之「櫃買市場海外法人說明會」。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6279',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '08:54:59',
#                       '8437',
#                       '大地-KY',
#                       '代子公司珠海大地軟件科技有限公司依公開發行公司資金貸與\r\n及背書保證處理準則第二十五條第一項第四款公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8437',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '08:55:23',
#                       '8437',
#                       '大地-KY',
#                       '代子公司珠海美地教育諮詢有限公司依公開發行公司資金貸與及\r\n背書保證處理準則第二十五條第一項第四款公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8437',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '09:06:37',
#                       '8086',
#                       '宏捷科',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8086',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '09:09:07',
#                       '2718',
#                       '全心投控',
#                       '公告本公司名稱由「桃園大飯店股份有限公司」更名為「晶\r\n悅國際飯店股份有限公司」。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2718',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:21:17',
#                       '5228',
#                       '鈺鎧',
#                       '公告104年10月份自結財務報告之負債比率.流動比率及速動比率',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5228',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:43:06',
#                       '8358',
#                       '金居',
#                       '更正本公司104年第2季合併財務報告附註揭露事項之大陸投資資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8358',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:53:53',
#                       '4107',
#                       '邦特',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4107',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:53:58',
#                       '8096',
#                       '擎亞',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8096',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '10:56:44',
#                       '5213',
#                       '亞昕',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5213',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:04:09',
#                       '3522',
#                       '御嵿',
#                       '代重要子公司宏宇光學科技股份有限公司公告\r\n104年第一次股東臨時會重要決議事項',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3522',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:05:02',
#                       '3522',
#                       '御嵿',
#                       '代重要子公司宏宇光學科技股份有限公司公告\r\n董事會決議現金減資基準日。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3522',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '12:01:59',
#                       '8069',
#                       '元太',
#                       '澄清媒體之相關報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8069',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '12:14:07',
#                       '3081',
#                       '聯亞',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3081',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '13:26:14',
#                       '8916',
#                       '光隆',
#                       '本公司受邀參加元大證券舉辦之法人說明會(更正地址)',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8916',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:04:56',
#                       '4726',
#                       '永昕',
#                       '本公司受邀參加元富證券舉辦之「生技產業暨投資論壇」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4726',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:06:58',
#                       '8092',
#                       '建暐',
#                       '公告本公司董事會決議擬撤銷發行\r\n國內第三次有擔保轉換公司債案',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8092',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:19:51',
#                       '6488',
#                       '環球晶',
#                       '本公司受邀參加104年11月24日至104年11月27日櫃買中心與麥格理證券於新加坡、香港合作舉辦之海外法說會。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6488',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '15:52:43',
#                       '3073',
#                       '天方能源',
#                       '公告本公司收到財政部北區國稅局補徵101年營利事業所得稅\r\n新台幣10,220,587元',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3073',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:30:24',
#                       '6275',
#                       '元山',
#                       '代子公司Y H Tech International Corp.公告新增\r\n'
#                       '資金貸與金額達新台幣一千萬元以上且達該公開發\r\n'
#                       '行公司最近期財務報表淨值百分之二以上',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6275',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:51:52',
#                       '6248',
#                       '沛波',
#                       '公告本公司辦理減資案完成資本額變更登記之預計換股作業計畫',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6248',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '16:54:24',
#                       '4556',
#                       '旭然',
#                       '本公司上櫃前業績發表會公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4556',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '16:55:47',
#                       '4556',
#                       '旭然',
#                       '公告本公司股票初次上櫃前現金增資發行新股事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4556',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:00:40',
#                       '6114',
#                       '久威',
#                       '依櫃檯買賣中心證櫃監字第0970200896號函辦理',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6114',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:04:00',
#                       '4167',
#                       '松瑞藥',
#                       '公告本公司限制員工權利新股註銷減資基準日',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4167',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:26:22',
#                       '8069',
#                       '元太',
#                       '公告本公司將逐步降低LCD業務比重說明',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8069',
#                                       'enterDate': '1041120',
#                                       'marketKind': 'otc',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '16:24:27',
#                       '3633',
#                       '云光',
#                       '公告本公司董事會推選董事長',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3633',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '08:35:10',
#                       '2311',
#                       '日月光',
#                       '對矽品精密工業股份有限公司104/11/20重大訊息公告內容\r\n提出說明',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2311',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '09:42:19',
#                       '1818',
#                       '願景國際',
#                       '公告104年10月份自結合併財務報告之負債比率、\r\n流動比率及速動比率',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1818',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '11:30:46',
#                       '4103',
#                       '百略醫學',
#                       '澄清經濟日報104/11/22報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4103',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '13:20:52',
#                       '3662',
#                       '齊民',
#                       '公告本公司董事會決議104年第1次私募普通股定價日及私募\r\n價格等相關事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3662',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
# ...
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4733',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 6}}],
#                      ['104/11/23',
#                       '16:49:21',
#                       '4733',
#                       '上緯企業',
#                       '公告本公司董事會決議通過註銷庫藏股暨訂定辦理減資基準日',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4733',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:51:13',
#                       '5229',
#                       '立宇',
#                       '本公司代子公司(Hwa Deng Investment(BVI) Limited)依資金\r\n'
#                       '貸與及背書保證處理準則第二十二條第一項第三款公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5229',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:51:35',
#                       '6514',
#                       '芮特-KY',
#                       '公告本公司股務代理機構名稱、辦公處所及聯絡電話',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6514',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:54:59',
#                       '2841',
#                       '台開',
#                       '台灣土地開發(股)公司公告新增對單一企業\r\n背書保證情形達處理準則第二十五條第一項第四款',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2841',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:03:24',
#                       '5259',
#                       '奕智博',
#                       '公告補正本公司104年第三季財報附註部份資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5259',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:05:01',
#                       '5506',
#                       '長鴻',
#                       '公告本公司退票事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5506',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:10:34',
#                       '3089',
#                       '億杰',
#                       '公告本公司董事會通過向關係人購買不動產之價格調整案。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3089',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:11:52',
#                       '8325',
#                       '中廣',
#                       '公告更正104年9月份衍生性商品交易資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8325',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:12:16',
#                       '3688',
#                       '華立捷',
#                       '公告本公司104年現金增資全體董事及監察人放棄認購股數\r\n達得認購股數1/2以上，並洽特定人認購事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3688',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 5}}],
#                      ['104/11/23',
#                       '17:17:14',
#                       '3536',
#                       '誠創',
#                       '公告本公司104年10月份高流動性資產、短期借款\r\n及一年內到期之長期負債相關財務資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3536',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:17:36',
#                       '4740',
#                       '慕德生',
#                       '代子公司Merit Biotech(Samoa) Co., Ltd.公告現金減資案',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4740',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '17:17:49',
#                       '4740',
#                       '慕德生',
#                       '代孫公司Merit Biotech(Cayman Islands) Co., Ltd.公告\r\n現金增資案',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4740',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '17:18:01',
#                       '4740',
#                       '慕德生',
#                       '公告本公司法人董事代表人指派',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4740',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 4}}],
#                      ['104/11/23',
#                       '17:44:07',
#                       '5216',
#                       '優燈',
#                       '公告本公司更換股務代理機構准予備查',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5216',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:48:20',
#                       '4803',
#                       'VHQ-KY',
#                       '公告本公司舉辦上櫃前業績發表會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4803',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:55:08',
#                       '4731',
#                       '東宇生技',
#                       '本公司董事異動達三分之一以上公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4731',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:59:06',
#                       '2809',
#                       '京城銀',
#                       '公告本行依國際會計準則公報第39號認列金融資產減損',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2809',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:59:11',
#                       '2888',
#                       '新光金',
#                       '代子公司新光海航人壽發布被中國保監會責令停止\r\n開展新業務事宜。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2888',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:59:39',
#                       '2888',
#                       '新光金',
#                       '本公司代子公司新光人壽公告處分 OmniTrend(USD) Fund',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2888',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 2}}],
#                      ['104/11/23',
#                       '18:02:17',
#                       '8115',
#                       '帝聞',
#                       '代子公司帝聞電子(深圳)有限公司公告處分理財產品',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8115',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '18:42:10',
#                       '3089',
#                       '億杰',
#                       '公告本公司法人監察人齊芯投資股份有限公司改派代表人',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3089',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '19:19:31',
#                       '6131',
#                       '鈞泰',
#                       '法人董事兩席辭職',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6131',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '19:23:15',
#                       '6131',
#                       '鈞泰',
#                       '公告本公司法人董事辭任，變動已達1/3',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6131',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 4}}],
#                      ['104/11/23',
#                       '19:41:43',
#                       '3662',
#                       '齊民',
#                       '依公開發行公司資金貸與及背書保證處理準則第二十五條公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3662',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 3}}],
#                      ['104/11/23',
#                       '19:49:46',
#                       '4703',
#                       '揚華',
#                       '11/23公告未來一周營運資金運用狀況、銀行額度使用情形\r\n及存貨去化情形',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4703',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '21:04:10',
#                       '2475',
#                       '華映',
#                       '代子公司(福建華佳彩有限公司)公告取得土地使用權',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2475',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '12:30:26',
#                       '911626',
#                       'MSH-DR',
#                       '華運(中國)控股有限公司截至2015年9月30日財務報告',
#                       {'apiName': 't59sb01_detail',
#                        'parameters': {'companyId': '911626',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:08:53',
#                       '9103',
#                       '美德醫療-DR',
#                       '係因本公司有價證券於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊，以利投資人區別瞭解。',
#                       {'apiName': 't59sb01_detail',
#                        'parameters': {'companyId': '9103',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:09:36',
#                       '911622',
#                       '泰聚亨-DR',
#                       '係因本公司有價證券於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊，以利投資人區別瞭解。',
#                       {'apiName': 't59sb01_detail',
#                        'parameters': {'companyId': '911622',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '16:20:00',
#                       '913889',
#                       '大成糖',
#                       '因大成糖業臺灣存託憑證於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊',
#                       {'apiName': 't59sb01_detail',
#                        'parameters': {'companyId': '913889',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:00:35',
#                       '910801',
#                       '金衛-DR',
#                       '金衛醫療集團有限公司派發截至104年3月31日止年度末期股息之以股代息事宜公告',
#                       {'apiName': 't59sb01_detail',
#                        'parameters': {'companyId': '910801',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['104/11/23',
#                       '17:09:45',
#                       '913889',
#                       '大成糖',
#                       '補充:因大成糖業臺灣存託憑證於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊',
#                       {'apiName': 't59sb01_detail',
#                        'parameters': {'companyId': '913889',
#                                       'enterDate': '1041123',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}]],
#             'titles': [{'main': '發言日期', 'sub': []},
#                        {'main': '發言時間', 'sub': []},
#                        {'main': '公司代號', 'sub': []},
#                        {'main': '公司名稱', 'sub': []},
#                        {'main': '主旨', 'sub': []},
#                        {'main': '詳細資料', 'sub': []}]}}

# %%
# 整理資料
df = pd.DataFrame(data['result']['data'], columns=["date", "time", "companyId", "companyName", "title", "raw"])

# apiName 直接取文字
df["apiName"] = df["raw"].apply(lambda x: x["apiName"])

# parameters 保留 dict
df["parameters"] = df["raw"].apply(lambda x: x["parameters"])

# 移除 raw 欄
df = df.drop(columns=["raw"])

# %%
df
# Out:
#           date      time companyId companyName  \
# 0    104/11/23  08:36:08      9802       鈺齊-KY
# 1    104/11/23  08:59:02      1339          昭輝
# 2    104/11/23  09:03:19      2345          智邦
# 3    104/11/23  09:09:24      3003         健和興
# 4    104/11/23  09:49:53      9910          豐泰
# ..         ...       ...       ...         ...
# 136  104/11/23  16:08:53      9103     美德醫療-DR
# 137  104/11/23  16:09:36    911622      泰聚亨-DR
# 138  104/11/23  16:20:00    913889         大成糖
# 139  104/11/23  17:00:35    910801       金衛-DR
# 140  104/11/23  17:09:45    913889         大成糖
#
#                                                  title         apiName  \
# 0    公告本公司受邀參加麥格理證&#21173;、台灣證&#21173;交易所及證券櫃檯買賣中心合...  t05st02_detail
# 1                               公告本公司第一次買回庫藏股期間屆滿及執行狀況  t05st02_detail
# 2                                 澄清 11/23 自由時報對本公司之報導  t05st02_detail
# 3                                               澄清媒體報導  t05st02_detail
# 4        本公司受邀參加麥格理證券舉辦之「North Asia Corporate Day」視訊會議  t05st02_detail
# ..                                                 ...             ...
# 136  係因本公司有價證券於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊，以利...  t59sb01_detail
# 137  係因本公司有價證券於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊，以利...  t59sb01_detail
# 138      因大成糖業臺灣存託憑證於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊  t59sb01_detail
# 139            金衛醫療集團有限公司派發截至104年3月31日止年度末期股息之以股代息事宜公告  t59sb01_detail
# 140   補充:因大成糖業臺灣存託憑證於集中交易市場達公布注意交易資訊標準，故公布原上市地已公開之財務資訊  t59sb01_detail
#
#                                             parameters
# 0    {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 1    {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 2    {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 3    {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 4    {'enterDate': '1041123', 'serialNumber': 1, 'c...
# ..                                                 ...
# 136  {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 137  {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 138  {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 139  {'enterDate': '1041123', 'serialNumber': 1, 'c...
# 140  {'enterDate': '1041123', 'serialNumber': 2, 'c...
#
# [141 rows x 7 columns]

# %%
ix = 0

# POST參數
payload = df['parameters'].iloc[ix]

# 目標網址
url = "https://mops.twse.com.tw/mops/api/t05st02_detail"

# 發送 POST 請求
headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/json",
}
response = requests.post(url, json=payload, headers=headers)
print("Status Code:", response.status_code)

# 讀取網頁
html = response.text

# 解析網頁
data = response.json()
print("Response JSON:")
pprint(data)
# Out:
# Status Code: 200
# Response JSON:
# {'code': 200,
#  'datetime': '114/11/23 10:47:24',
#  'message': '查詢成功',
#  'result': {'companyAbbreviation': '鈺齊-KY',
#             'companyId': '9802',
#             'data': [[1,
#                       '104/11/23',
#                       '08:36:08',
#                       '廖志誠',
#                       '執行副總',
#                       '(886)55514619',
#                       '公告本公司受邀參加麥格理證&#21173;、台灣證&#21173;交易所及證券櫃檯買賣中心合辦之「Taiwan '
#                       'corporate day」',
#                       '12',
#                       '104/11/24',
#                       '符合條款第四條第XX款：12\r\n'
#                       '事實發生日：104/11/24\r\n'
#                       '1.召開法人說明會之日期：104/11/24\r\n'
#                       '2.召開法人說明會之時間：09 時 00 分 \r\n'
#                       '3.召開法人說明會之地點：新加坡 Fullerton Hotel\r\n'
#                       '4.法人說明會擇要訊息：受邀參加麥格理證&#21173;、台灣證&#21173;交易所及證券櫃檯買賣中心合辦之「Taiwan '
#                       'corporate day」，就本公司財務及業務相關資訊做說明。\r\n'
#                       '5.其他應敘明事項：無\r\n'
#                       '完整財務業務資訊請至公開資訊觀測站之法人說明會一覽表或法說會項目下查閱。']],
#             'footer': ['以上資料均由各公司依發言當時所屬市場別之規定申報後，由本系統對外公佈，資料如有虛偽不實，均由該公司負責。'],
#             'header': {'mainTitle': ['公司當日重大訊息之詳細內容'],
#                        'note': [],
#                        'subTitle': []},
#             'marketName': '上市公司',
#             'titles': [{'main': '序號', 'sub': []},
#                        {'main': '發言日期', 'sub': []},
#                        {'main': '發言時間', 'sub': []},
#                        {'main': '發言人', 'sub': []},
#                        {'main': '發言人職稱', 'sub': []},
#                        {'main': '發言人電話', 'sub': []},
#                        {'main': '主旨', 'sub': []},
#                        {'main': '符合條款', 'sub': []},
#                        {'main': '事實發生日', 'sub': []},
#                        {'main': '說明', 'sub': []}]}}

# %%
# 解析欄位名稱
columns = [t['main'] for t in data['result']['titles']]

# 建立 DataFrame
output = pd.DataFrame(data['result']['data'], columns=columns)

# %%
output
# Out:
#    序號       發言日期      發言時間  發言人 發言人職稱          發言人電話  \
# 0   1  104/11/23  08:36:08  廖志誠  執行副總  (886)55514619
#
#                                                   主旨 符合條款      事實發生日  \
# 0  公告本公司受邀參加麥格理證&#21173;、台灣證&#21173;交易所及證券櫃檯買賣中心合...   12  104/11/24
#
#                                                   說明
# 0  符合條款第四條第XX款：12\r\n事實發生日：104/11/24\r\n1.召開法人說明會...

# %%
# 整合成迴圈
output = pd.DataFrame()
# for ix in range(len(df)):
for ix in range(5):

    print(f"目前正在下載: {df['companyName'].iloc[ix]} 財報資料 進度: {ix+1} / {len(df)}")

    # POST參數
    payload = df['parameters'].iloc[ix]

    # 目標網址
    url = "https://mops.twse.com.tw/mops/api/t05st02_detail"

    # 發送 POST 請求
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Content-Type": "application/json",
    }
    response = requests.post(url, json=payload, headers=headers)
    print("Status Code:", response.status_code)

    # 讀取網頁
    html = response.text

    # 解析網頁
    data = response.json()

    # 解析欄位名稱
    columns = [t['main'] for t in data['result']['titles']]

    # 建立 DataFrame
    iOutput = pd.DataFrame(data['result']['data'], columns=columns)

    # 儲存 DataFrame
    output = pd.concat([output, iOutput], ignore_index=True)

    # 暫停時間 避免爬取過快
    time.sleep(random.randint(1, 3))
# Out:
# 目前正在下載: 鈺齊-KY 財報資料 進度: 1 / 141
# Status Code: 200
# 目前正在下載: 昭輝 財報資料 進度: 2 / 141
# Status Code: 200
# 目前正在下載: 智邦 財報資料 進度: 3 / 141
# Status Code: 200
# 目前正在下載: 健和興 財報資料 進度: 4 / 141
# Status Code: 200
# 目前正在下載: 豐泰 財報資料 進度: 5 / 141
# Status Code: 200
