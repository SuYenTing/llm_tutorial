# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from pprint import pprint
import time
import random

# %%
# MOPS搜尋頁面
url = "https://mops.twse.com.tw/mops/api/t05st02"

payload = {
    "year":"114",
    "month":"11",
    "day":"21"
}

headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/json",
}

# 發送 POST 請求
response = requests.post(url, json=payload, headers=headers, verify=False)

print("Status Code:", response.status_code)

# 解析 JSON（若回傳為 JSON）
try:
    data = response.json()
    print("Response JSON:")
    pprint(data)
except Exception:
    print("Response Text:")
    print(response.text)
# Out:
# c:\Users\User\github\llm_tutorial\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# Status Code: 200
# Response JSON:
# {'code': 200,
#  'datetime': '114/11/23 20:56:15',
#  'message': '查詢成功',
#  'result': {'data': [['114/11/20',
#                       '17:39:01',
#                       '2327',
#                       '國巨*',
#                       '本公司受邀參加由Citi舉辦之"Citi Taiwan Corporate Day"',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2327',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '17:39:42',
#                       '2323',
#                       '中環',
#                       '公告本公司處分有價證券',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2323',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '17:41:35',
#                       '2323',
#                       '中環',
#                       '公告本公司處分有價證券',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2323',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/20',
#                       '17:43:56',
#                       '2460',
#                       '建通',
#                       '公告本公司召開法人說明會相關資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2460',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/20',
#                       '17:53:21',
#                       '3045',
#                       '台灣大',
#                       '公告取得台灣固網(股)公司一筆使用權資產',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3045',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '17:53:27',
#                       '2883',
#                       '凱基金',
#                       '凱基金控(原名稱:開發金控)訂於114年12月2日召開\r\n114年第3季法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2883',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '17:53:47',
#                       '2883',
#                       '凱基金',
#                       '代子公司凱基人壽公告董事會決議擬以公開募集方式\r\n發行十年(含)以上累積次順位公司債',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2883',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/20',
#                       '17:54:08',
#                       '2883',
#                       '凱基金',
#                       '代子公司凱基人壽公告董事會決議裁撤澎湖分公司',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2883',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/20',
#                       '17:57:40',
#                       '9904',
#                       '寶成',
#                       '本公司受邀參加元大證券舉辦之線上法說會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '9904',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '18:10:55',
#                       '6706',
#                       '惠特',
#                       '公告本公司受邀參加凱基證券舉辦之法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6706',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '18:11:47',
#                       '5215',
#                       '科嘉-KY',
#                       '代子公司蘇州嘉吉/科德/嘉財/艾普來/百宏/嘉皇/嘉駿 \r\n'
#                       '公告一年內累積處分同一有價證券達實收資本額20%',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5215',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '18:12:02',
#                       '5215',
#                       '科嘉-KY',
#                       '代子公司蘇州嘉吉/科德/嘉財/艾普來/百宏/嘉皇/嘉駿 \r\n'
#                       '公告一年內累積取得同一有價證券達實收資本額20%',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5215',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/20',
#                       '18:14:38',
#                       '1598',
#                       '岱宇',
#                       '公告本公司第七次買回庫藏股執行完畢情形\r\n(更正本次已買回股份總金額)',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1598',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '18:15:45',
#                       '1432',
#                       '大魯閣',
#                       '本公司董事會通過處分台中新時代購物中心、\r\n新竹湳雅廣場營業資產、權利及義務授權董事長簽署營業讓與契約',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1432',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '18:16:06',
#                       '1432',
#                       '大魯閣',
#                       '公告本公司與交易相對人簽署營業讓與契約。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1432',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/20',
#                       '18:30:08',
#                       '2887',
#                       '台新新光金',
#                       '本公司代子公司台新銀行公告擬全額認購其子公司台新大安租賃\r\n(股)公司辦理之現金增資發行普通股',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2887',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/20',
#                       '18:31:07',
#                       '2887',
#                       '台新新光金',
#                       '本公司代子公司新光金創投公告其董事會通過處份子公司所持有的\r\n新光租賃(蘇州)有限公司100%出資額',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2887',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '18:42:28',
#                       '3027',
#                       '盛達',
#                       '更正114年8月份背書保證資訊揭露明細表',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3027',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '18:46:41',
#                       '2887',
#                       '台新新光金',
#                       '本公司代子公司台新大安租賃公告向Lion(Samoa)購買新光租賃(蘇州)\r\n'
#                       '有限公司(大陸地區)100%出資額',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2887',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/20',
#                       '20:51:48',
#                       '1589',
#                       '永冠-KY',
#                       '公告本公司114年現金增資發行新股已依中國證監會發布之「境內\r\n'
#                       '企業境外發行證券和上市管理試行辦法」進行備案',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1589',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/20',
#                       '21:00:26',
#                       '6873',
#                       '泓德能源',
#                       '本公司配合檢調單位進行調查',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6873',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/20',
#                       '21:02:40',
#                       '2236',
#                       '百達-KY',
#                       '公告本公司新增背書保證金額達第二十五條第一項\r\n第一款之標準。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2236',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/20',
#                       '21:02:58',
#                       '2236',
#                       '百達-KY',
#                       '公告本公司新增背書保證金額達第二十五條第一項\r\n第一款之標準',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2236',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/20',
#                       '21:20:24',
#                       '1504',
#                       '東元',
#                       '公告本公司法人董事改派代表人',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1504',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '07:00:03',
#                       '8422',
#                       '可寧衛*',
#                       '公告本公司股票面額由「新台幣10元」變更為「新台幣1元」，\r\n'
#                       '公告期間：114年10月16日至115年01月15日。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8422',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '09:55:03',
#                       '6515',
#                       '穎崴',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6515',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '10:03:36',
#                       '7610',
#                       '聯友金屬-創',
#                       '代重要子公司聯友能源科技股份有限公司公告修訂公司章程',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7610',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '10:27:09',
#                       '1101',
#                       '台泥',
#                       '公告本公司蘇澳廠火災情形及因應措施',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1101',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '10:36:22',
#                       '3005',
#                       '神基',
#                       '澄清114年11月21日經濟日報報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3005',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '10:45:59',
#                       '8374',
#                       '羅昇',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8374',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '10:46:43',
#                       '2313',
#                       '華通',
#                       '本公司受邀參加花旗環球證券舉辦之「Taiwan Corporate Day」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2313',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '10:48:41',
#                       '5243',
#                       '乙盛-KY',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5243',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '10:54:50',
#                       '2884',
#                       '玉山金',
#                       '澄清媒體報導',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2884',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '10:57:07',
#                       '6965',
#                       '中傑-KY',
#                       '本公司受邀參加由元大證券舉辦之線上法人說明會，說明本公司營運概況及未來展望。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6965',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:37:41',
#                       '4766',
#                       '南寶',
#                       '代重要子公司台灣艾富克股份有限公司公告\r\n董事會決議辦理現金減資',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4766',
#                                       'enterDate': '1141119',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:46:49',
#                       '2836',
#                       '高雄銀',
#                       '公告本公司召開2025年第3季法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2836',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:47:15',
#                       '1466',
#                       '聚隆',
#                       '公告更正本公司114年度10月份背書保證累計至本月最高餘額及\r\n期末背書保證餘額申報資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1466',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:48:03',
#                       '3518',
#                       '柏騰',
#                       '公告本公司及子公司達公開發行公司資金貸與及背書保證處理\r\n準則第二十二條第一項第三款',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3518',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:50:18',
#                       '6771',
#                       '平和環保-創',
#                       '本公司受邀參加福邦證券舉辦之法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6771',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:54:31',
#                       '2387',
#                       '精元',
#                       '2025年第三季線上法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2387',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:56:54',
#                       '2207',
#                       '和泰車',
#                       '公告本公司將受邀參加台新證券所舉辦之法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2207',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '13:57:32',
#                       '3518',
#                       '柏騰',
#                       '公告本公司召開法人說明會相關資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3518',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '14:00:16',
#                       '2912',
#                       '統一超',
#                       '本公司受邀參加花旗環球證券於台北文華東方酒店舉辦之法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2912',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:02:33',
#                       '5285',
#                       '界霖',
#                       '本公司受邀參加宏遠證券舉辦線上法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5285',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:03:05',
#                       '6165',
#                       '浪凡',
#                       '公告本公司董事會決議買回本公司股份',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6165',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:14:22',
#                       '6282',
#                       '康舒',
#                       '代重要子公司OmniOn Power Holdings Inc.公告指派董事',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6282',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '14:14:38',
#                       '6282',
#                       '康舒',
#                       '代重要子公司OmniOn Power Inc.公告指派董事',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6282',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 4}}],
#                      ['114/11/21',
#                       '14:16:06',
#                       '1477',
#                       '聚陽',
#                       '本公司受邀參加花旗證券舉辦之「2025 Taiwan Corporate Day」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1477',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:17:00',
#                       '2530',
#                       '華建',
#                       '公告本公司調整114年度第三季現金股利配息率',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2530',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:22:08',
#                       '8462',
#                       '柏文',
#                       '公告本公司辦理註銷買回限制員工權利新股減資變更\r\n登記完成',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '8462',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:30:34',
#                       '6805',
#                       '富世達',
#                       '本公司受邀參加台新證券舉辦之投資論壇',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6805',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:42:17',
#                       '2465',
#                       '麗臺',
#                       '公告本公司114年現金增資發行新股已依中國證監會發布之\r\n'
#                       '「境內企業境外發行證券和上市管理試行辦法」進行備案',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2465',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:56:19',
#                       '2408',
#                       '南亞科',
#                       '本公司受邀參加Morgan Stanley Post AP Summit Taiwan Tech Trip',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2408',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:56:52',
#                       '6213',
#                       '聯茂',
#                       '本公司受邀參加花旗證券舉辦之Citi Taiwan Corporate Day',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6213',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:03:56',
#                       '2492',
#                       '華新科',
#                       '公告本公司向關係人處分(轉租)使用權資產(提前終止租約)',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2492',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:06:00',
#                       '6414',
#                       '樺漢',
#                       '本公司配合114年第三季合併財報之會計師調整數，\r\n更正本公司原114年9月及10月營收公告數',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6414',
#                                       'enterDate': '1141119',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '15:18:51',
#                       '1612',
#                       '宏泰',
#                       '本公司受邀參加福邦證券舉辦之法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1612',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:23:02',
#                       '4958',
#                       '臻鼎-KY',
#                       '本公司受邀參加Morgan Stanley舉辦之「Post AP-Summit Taiwan Tech '
#                       'Trip」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4958',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:23:22',
#                       '3032',
#                       '偉訓',
#                       '公告本公司國內第二次無擔保轉換公司債收足價款',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3032',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:23:24',
#                       '4958',
#                       '臻鼎-KY',
#                       '本公司受邀參加BNP Paribas舉辦之「BNP Paribas TIME投資論壇」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4958',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '15:28:13',
#                       '2017',
#                       '官田鋼',
#                       '公告本公司114年10月自結合併損益',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2017',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:32:55',
#                       '3034',
#                       '聯詠',
#                       '本公司受邀參加由花旗證券所舉辦"Citi 2025 Taiwan Corporate Day"',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3034',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:34:48',
#                       '1102',
#                       '亞泥',
#                       '代子公司亞洲水泥(新加坡)私人有限公司公告原取得使用權資產\r\n租賃範圍調整',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1102',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:35:36',
#                       '1102',
#                       '亞泥',
#                       '代子公司亞東工業投資私人有限公司公告取得不動產使用權資產',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1102',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '15:37:21',
#                       '1326',
#                       '台化',
#                       '代子公司台塑生醫公司公告處分資產',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1326',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:39:49',
#                       '5907',
#                       '大洋-KY',
#                       '代子公司福州市大洋晶典商業有限公司公告新增背書保證金額\r\n'
#                       '達處理準則第25條第一項第二款、第三款及第四款公告標準',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5907',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:40:06',
#                       '5907',
#                       '大洋-KY',
#                       '代子公司武漢大洋晶典商業發展有限責任公司公告新增背書保證\r\n'
#                       '金額達處理準則第25條第一項第二款、第三款及第四款公告標準',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5907',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '15:40:26',
#                       '5907',
#                       '大洋-KY',
#                       '代重要子公司大洋晶典商業集團有限公司公告新增背書\r\n保證金額達處理準則第25條第一項第四款公告標準',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5907',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '15:40:42',
#                       '5907',
#                       '大洋-KY',
#                       '代子公司福州大洋商業有限公司公告新增背書保證\r\n金額達處理準則第25條第一項第四款公告標準',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5907',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 4}}],
#                      ['114/11/21',
#                       '15:41:12',
#                       '2313',
#                       '華通',
#                       '本公司受邀參加統一證券舉辦之「統一證券全球展望 冬季投資論壇」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2313',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '15:44:10',
#                       '3037',
#                       '欣興',
#                       '本公司受邀參加Citi證券舉辦之Citi’s 2025 Taiwan Corporate Day',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3037',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:44:28',
#                       '3037',
#                       '欣興',
#                       '本公司受邀參加富邦證券舉辦之2025第四季富邦企業日',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3037',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '15:47:50',
#                       '2337',
#                       '旺宏',
#                       '本公司受邀參加投資法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2337',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:47:53',
#                       '3716',
#                       '中化控股',
#                       '代子公司「中國化學製藥(股)公司」公告\r\n法人監察人改派代表人',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3716',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:48:19',
#                       '1210',
#                       '大成',
#                       '本公司取得不動產公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1210',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:48:21',
#                       '3028',
#                       '增你強',
#                       '公告本公司發言人及代理發言人異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3028',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:48:24',
#                       '3716',
#                       '中化控股',
#                       '代子公司「中化裕民健康事業(股)公司」公告\r\n法人監察人改派代表人',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3716',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '15:48:40',
#                       '2382',
#                       '廣達',
#                       '代子公司QMN(Quanta Manufacturing Nashville LLC)\r\n公告取得機器設備',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2382',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:49:23',
#                       '6799',
#                       '來頡',
#                       '本公司受邀參加元大證券舉辦之線上法人說明會，說明本公司114年第3季營運與財務概況',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6799',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:50:29',
#                       '2013',
#                       '中鋼構',
#                       '對本公司前員工、協力廠商負責人及相關人等共11人\r\n經檢察官起訴詐欺、背信罪等事宜。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2013',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:57:44',
#                       '2368',
#                       '金像電',
#                       '公告本公司國內第三次無擔保轉換公司債收足債款',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2368',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:57:57',
#                       '5880',
#                       '合庫金',
#                       '公告本公司經審計委員會同意及董事會決議通過114年\r\n第3季合併財務報告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5880',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '15:59:11',
#                       '5880',
#                       '合庫金',
#                       '公告本公司召開2025年第3季中文法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5880',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '15:59:57',
#                       '3050',
#                       '鈺德',
#                       '代重要子公司大樂司文創股份有限公司公告總經理/稽核主\r\n管異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3050',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:00:53',
#                       '3050',
#                       '鈺德',
#                       '代公告本公司重要子公司大樂司文創股份有限公司\r\n董事會重要決議',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '3050',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '16:01:00',
#                       '6456',
#                       'GIS-KY',
#                       '代重要子公司公告董事異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6456',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:01:13',
#                       '2885',
#                       '元大金',
#                       '元大金控公告114年第三季合併財務報告經董事會決議通過',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2885',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:02:28',
#                       '5388',
#                       '中磊',
#                       "本公司受邀參加花旗證券舉辦之Citi's 2025 Taiwan Corporate Day投資論壇",
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5388',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '16:05:11',
#                       '6431',
#                       '光麗-KY',
#                       '公告本公司總經理及子公司Novel Idea Co.,Ltd.\r\n董事長及總經理異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6431',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:05:23',
#                       '1201',
#                       '味全',
#                       '本公司受邀參加元大證券舉辦之線上產業座談會。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1201',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:10:22',
#                       '6431',
#                       '光麗-KY',
#                       '公告本公司董事及子公司董事及監事異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6431',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '16:13:32',
#                       '2890',
#                       '永豐金',
#                       '公告本公司114年第3季合併財務報告經董事會決議通過',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2890',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:14:13',
#                       '2890',
#                       '永豐金',
#                       '永豐金控公告本公司受邀參加UBS APAC Financials, Fintech and Property '
#                       'Corporate Day 2025',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2890',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '16:14:51',
#                       '2890',
#                       '永豐金',
#                       '永豐金控公告董事會決議子公司永豐投顧法人董事代表人\r\n異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2890',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '16:15:28',
#                       '2890',
#                       '永豐金',
#                       '永豐金控公告董事會決議子公司永豐金證券(亞洲)有限\r\n公司法人董事代表人異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2890',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 8}}],
#                      ['114/11/21',
#                       '16:15:36',
#                       '4739',
#                       '康普',
#                       '公告本公司國內第四次有擔保轉換公司債代收價款及存儲專戶行庫',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4739',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:16:34',
#                       '2890',
#                       '永豐金',
#                       '永豐金控公告董事會決議子公司永豐證券\r\n投資顧問股份有限公司總經理異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2890',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 6}}],
#                      ['114/11/21',
#                       '16:17:47',
#                       '2890',
#                       '永豐金',
#                       '永豐金控公告董事會決議子公司永豐證券\r\n投資顧問股份有限公司研調主管異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2890',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
#                                       'serialNumber': 7}}],
#                      ['114/11/21',
#                       '16:24:01',
#                       '4989',
#                       '榮科',
#                       '代母公司李長榮化學工業股份有限公司\r\n公告處分李長榮科技股份有限公司股權',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4989',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'sii',
# ...
#                      ['114/11/21',
#                       '16:09:10',
#                       '6027',
#                       '德信',
#                       '公告本公司代理發言人異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6027',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:12:08',
#                       '7821',
#                       '神數',
#                       '更正本公司114年第三季、114年第二季、113年度合併及個體\r\n'
#                       '及112年度合併及個體財務報表附註暨114年第三季iXBRL申報資訊',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7821',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:12:10',
#                       '6614',
#                       '資拓宏宇',
#                       '本公司股票即將終止興櫃交易並轉至臺灣證券交易所上市交易',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6614',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:12:29',
#                       '6614',
#                       '資拓宏宇',
#                       '本公司辦理股票初次上市前現金增資收足股款暨現金增資基準日',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6614',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '16:12:46',
#                       '6614',
#                       '資拓宏宇',
#                       '本公司辦理股票初次上市過額配售內容',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6614',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '16:35:09',
#                       '7810',
#                       '捷創科技',
#                       '公告本公司將於114年11月27日舉行上櫃前業績發表會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7810',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:37:01',
#                       '6910',
#                       '德鴻',
#                       '公告本公司股票初次上櫃前現金增資暫定承銷\r\n價格相關事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6910',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:38:17',
#                       '6910',
#                       '德鴻',
#                       '公告本公司股務代理機構名稱、辦公處所及聯絡\r\n電話',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6910',
#                                       'enterDate': '1141111',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 4}}],
#                      ['114/11/21',
#                       '16:38:19',
#                       '7427',
#                       '華上生醫',
#                       '公告本公司第二次買回庫藏股已執行完畢情形',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7427',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:51:19',
#                       '6780',
#                       '學習王',
#                       '公告本公司內部稽核主管異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6780',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '16:56:05',
#                       '4732',
#                       '彥臣',
#                       '代子公司公告本公司自主研發新藥NBM-BMX獲得美國食品\r\n'
#                       '藥物管理局(FDA)授予治療葡萄膜黑色素瘤之孤兒藥認定資格\r\n'
#                       '(ODD)',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '4732',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '17:12:26',
#                       '6839',
#                       '開陽能源',
#                       '公告本公司董事會決議買回庫藏股事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6839',
#                                       'enterDate': '1141120',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '17:29:17',
#                       '6474',
#                       '華豫寧',
#                       '公告本公司股票初次上櫃前現金增資收足股款暨現金增資基準日',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6474',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '17:29:33',
#                       '6474',
#                       '華豫寧',
#                       '公告本公司辦理股票初次上櫃過額配售內容',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6474',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '17:29:43',
#                       '6474',
#                       '華豫寧',
#                       '公告本公司113年度員工認股權憑證認股價格調整',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6474',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '17:31:41',
#                       '2758',
#                       '路易莎咖啡',
#                       '本公司依資金貸與及背書保證準則第二十五條第一項第四款公告',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2758',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '17:56:20',
#                       '1271',
#                       '晨暉生技',
#                       '公告本公司內部稽核主管異動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '1271',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '19:31:46',
#                       '7769',
#                       '鴻勁',
#                       '本公司股票初次上市前現金增資員工認購股款催繳事宜',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7769',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '19:33:22',
#                       '7769',
#                       '鴻勁',
#                       '本公司辦理股票初次上市過額配售內容',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7769',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '20:46:34',
#                       '7850',
#                       '寶泰生醫',
#                       '公告本公司114年第二次股東臨時會重要決議事項',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7850',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '20:47:14',
#                       '7850',
#                       '寶泰生醫',
#                       '公告本公司114年第二次股東臨時會全面改選董事(含獨立董事)\r\n暨三分之一以上董事之變動',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7850',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 3}}],
#                      ['114/11/21',
#                       '20:47:41',
#                       '7850',
#                       '寶泰生醫',
#                       '公告本公司114年第二次股東臨時會通過解除新任董事競業禁止\r\n之限制',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7850',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 4}}],
#                      ['114/11/21',
#                       '20:48:01',
#                       '7850',
#                       '寶泰生醫',
#                       '公告本公司董事會選任董事長及副董事長',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7850',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 5}}],
#                      ['114/11/21',
#                       '20:48:26',
#                       '7850',
#                       '寶泰生醫',
#                       '公告本公司成立第一屆審計委員會及委任第二屆薪資報酬委\r\n員會委員',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7850',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 6}}],
#                      ['114/11/21',
#                       '20:48:47',
#                       '7850',
#                       '寶泰生醫',
#                       '公告本公司法人董事指派代表人',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7850',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'rotc',
#                                       'serialNumber': 7}}],
#                      ['114/11/21',
#                       '09:13:33',
#                       '5868',
#                       '臺灣金控',
#                       '本公司財務主管及公司治理主管異動案。',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '5868',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '11:42:21',
#                       '7669',
#                       '碩正科技',
#                       '公告本公司受邀參加元大證券舉辦之興櫃前法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7669',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '13:57:25',
#                       '6287',
#                       '元隆',
#                       '公告本公司董事會決議申請停止股票公開發行案',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6287',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '14:02:27',
#                       '6287',
#                       '元隆',
#                       '本公司董事會決議召開115年第1次股東臨時會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6287',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 2}}],
#                      ['114/11/21',
#                       '16:06:07',
#                       '2873',
#                       '大中票券',
#                       '公告本公司新任薪酬委員會委員',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2873',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '17:24:47',
#                       '6475',
#                       '岱煒',
#                       '公告經濟部商業司核准本公司\r\n變更名稱為「智賦科技股份有限公司」',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '6475',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '17:40:46',
#                       '7878',
#                       '藥祇',
#                       '本公司受邀參加兆豐證券舉辦之興櫃前法人說明會',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '7878',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}],
#                      ['114/11/21',
#                       '17:47:16',
#                       '2750',
#                       '桃禧',
#                       '公告本公司一一四年股東臨時會決議事項',
#                       {'apiName': 't05st02_detail',
#                        'parameters': {'companyId': '2750',
#                                       'enterDate': '1141121',
#                                       'marketKind': 'pub',
#                                       'serialNumber': 1}}]],
#             'titles': [{'main': '發言日期', 'sub': []},
#                        {'main': '發言時間', 'sub': []},
#                        {'main': '公司代號', 'sub': []},
#                        {'main': '公司名稱', 'sub': []},
#                        {'main': '主旨', 'sub': []},
#                        {'main': '詳細資料', 'sub': []}]}}

# %%
# 整理資料
df = pd.DataFrame(data['result']['data'], columns=["date", "time", "companyId", "companyName", "title", "raw"])

# apiName 直接取文字
df["apiName"] = df["raw"].apply(lambda x: x["apiName"])

# parameters 保留 dict
df["parameters"] = df["raw"].apply(lambda x: x["parameters"])

# 移除 raw 欄
df = df.drop(columns=["raw"])

# %%
df
# Out:
#           date      time companyId companyName  \
# 0    114/11/20  17:39:01      2327         國巨*
# 1    114/11/20  17:39:42      2323          中環
# 2    114/11/20  17:41:35      2323          中環
# 3    114/11/20  17:43:56      2460          建通
# 4    114/11/20  17:53:21      3045         台灣大
# ..         ...       ...       ...         ...
# 250  114/11/21  14:02:27      6287          元隆
# 251  114/11/21  16:06:07      2873        大中票券
# 252  114/11/21  17:24:47      6475          岱煒
# 253  114/11/21  17:40:46      7878          藥祇
# 254  114/11/21  17:47:16      2750          桃禧
#
#                                           title         apiName  \
# 0    本公司受邀參加由Citi舉辦之"Citi Taiwan Corporate Day"  t05st02_detail
# 1                                   公告本公司處分有價證券  t05st02_detail
# 2                                   公告本公司處分有價證券  t05st02_detail
# 3                              公告本公司召開法人說明會相關資訊  t05st02_detail
# 4                          公告取得台灣固網(股)公司一筆使用權資產  t05st02_detail
# ..                                          ...             ...
# 250                      本公司董事會決議召開115年第1次股東臨時會  t05st02_detail
# 251                              公告本公司新任薪酬委員會委員  t05st02_detail
# 252          公告經濟部商業司核准本公司\r\n變更名稱為「智賦科技股份有限公司」  t05st02_detail
# 253                      本公司受邀參加兆豐證券舉辦之興櫃前法人說明會  t05st02_detail
# 254                          公告本公司一一四年股東臨時會決議事項  t05st02_detail
#
#                                             parameters
# 0    {'enterDate': '1141120', 'serialNumber': 1, 'c...
# 1    {'enterDate': '1141120', 'serialNumber': 1, 'c...
# 2    {'enterDate': '1141120', 'serialNumber': 2, 'c...
# 3    {'enterDate': '1141120', 'serialNumber': 2, 'c...
# 4    {'enterDate': '1141120', 'serialNumber': 1, 'c...
# ..                                                 ...
# 250  {'enterDate': '1141121', 'serialNumber': 2, 'c...
# 251  {'enterDate': '1141121', 'serialNumber': 1, 'c...
# 252  {'enterDate': '1141121', 'serialNumber': 1, 'c...
# 253  {'enterDate': '1141121', 'serialNumber': 1, 'c...
# 254  {'enterDate': '1141121', 'serialNumber': 1, 'c...
#
# [255 rows x 7 columns]

# %%
ix = 0

# POST參數
apiName	= df['apiName'].iloc[ix]
payload = df['parameters'].iloc[ix]

# 目標網址
url = f"https://mops.twse.com.tw/mops/api/{apiName}"

# 發送 POST 請求
headers = {
    "User-Agent": "Mozilla/5.0",
    "Content-Type": "application/json",
}
response = requests.post(url, json=payload, headers=headers, verify=False)
print("Status Code:", response.status_code)

# 解析網頁
data = response.json()
print("Response JSON:")
pprint(data)
# Out:
# Status Code: 200
# Response JSON:
# {'code': 200,
#  'datetime': '114/11/23 20:58:27',
#  'message': '查詢成功',
#  'result': {'companyAbbreviation': '國巨*',
#             'companyId': '2327',
#             'data': [[1,
#                       '114/11/20',
#                       '17:39:01',
#                       '張天成',
#                       '全球財務部 資深協理',
#                       '(02)6629-9999',
#                       '本公司受邀參加由Citi舉辦之"Citi Taiwan Corporate Day"',
#                       '12',
#                       '114/11/24',
#                       '符合條款第四條第XX款：12\r\n'
#                       '事實發生日：114/11/24\r\n'
#                       '1.召開法人說明會之日期：114/11/24\r\n'
#                       '2.召開法人說明會之時間：14 時 00 分 \r\n'
#                       '3.召開法人說明會之地點：台北東方文華酒店\r\n'
#                       '4.法人說明會擇要訊息：本公司於114/11/24受邀參加Citi舉辦之投資人說明會(Citi '
#                       'Taiwan \r\n'
#                       'Corporate Day) 就公司營運及產業概況向投資機構做說明。\r\n'
#                       '5.其他應敘明事項：公司網站https://www.yageogroup.com/About/InvestorRelations/InvestorConference\r\n'
#                       '完整財務業務資訊請至公開資訊觀測站之法人說明會一覽表或法說會項目下查閱。']],
#             'footer': ['以上資料均由各公司依發言當時所屬市場別之規定申報後，由本系統對外公佈，資料如有虛偽不實，均由該公司負責。'],
#             'header': {'mainTitle': ['公司當日重大訊息之詳細內容'],
#                        'note': [],
#                        'subTitle': []},
#             'marketName': '上市公司',
#             'titles': [{'main': '序號', 'sub': []},
#                        {'main': '發言日期', 'sub': []},
#                        {'main': '發言時間', 'sub': []},
#                        {'main': '發言人', 'sub': []},
#                        {'main': '發言人職稱', 'sub': []},
#                        {'main': '發言人電話', 'sub': []},
#                        {'main': '主旨', 'sub': []},
#                        {'main': '符合條款', 'sub': []},
#                        {'main': '事實發生日', 'sub': []},
#                        {'main': '說明', 'sub': []}]}}
# c:\Users\User\github\llm_tutorial\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
# 解析欄位名稱
columns = [t['main'] for t in data['result']['titles']]

# 建立 DataFrame
output = pd.DataFrame(data['result']['data'], columns=columns)

# %%
output
# Out:
#    序號       發言日期      發言時間  發言人       發言人職稱          發言人電話  \
# 0   1  114/11/20  17:39:01  張天成  全球財務部 資深協理  (02)6629-9999
#
#                                            主旨 符合條款      事實發生日  \
# 0  本公司受邀參加由Citi舉辦之"Citi Taiwan Corporate Day"   12  114/11/24
#
#                                                   說明
# 0  符合條款第四條第XX款：12\r\n事實發生日：114/11/24\r\n1.召開法人說明會...

# %%
# 整合成迴圈
output = pd.DataFrame()
# for ix in range(len(df)):
for ix in range(5):

    print(f"目前正在下載: {df['companyName'].iloc[ix]} 財報資料 進度: {ix+1} / {len(df)}")

    # POST參數
    apiName	= df['apiName'].iloc[ix]
    payload = df['parameters'].iloc[ix]

    # 目標網址
    url = f"https://mops.twse.com.tw/mops/api/{apiName}"

    # 發送 POST 請求
    headers = {
        "User-Agent": "Mozilla/5.0",
        "Content-Type": "application/json",
    }
    response = requests.post(url, json=payload, headers=headers, verify=False)
    print("Status Code:", response.status_code)

    # 解析網頁
    data = response.json()

    # 解析欄位名稱
    columns = [t['main'] for t in data['result']['titles']]

    # 建立 DataFrame
    iOutput = pd.DataFrame(data['result']['data'], columns=columns)

    # 儲存 DataFrame
    output = pd.concat([output, iOutput], ignore_index=True)

    # 暫停時間 避免爬取過快
    time.sleep(random.randint(1, 3))
# Out:
# 目前正在下載: 國巨* 財報資料 進度: 1 / 255
# Status Code: 200
# c:\Users\User\github\llm_tutorial\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 目前正在下載: 中環 財報資料 進度: 2 / 255
# Status Code: 200
# c:\Users\User\github\llm_tutorial\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 目前正在下載: 中環 財報資料 進度: 3 / 255
# Status Code: 200
# c:\Users\User\github\llm_tutorial\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 目前正在下載: 建通 財報資料 進度: 4 / 255
# Status Code: 200
# c:\Users\User\github\llm_tutorial\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# 目前正在下載: 台灣大 財報資料 進度: 5 / 255
# Status Code: 200
# c:\Users\User\github\llm_tutorial\.venv\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'mops.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
output
# Out:
#    序號       發言日期      發言時間  發言人       發言人職稱             發言人電話  \
# 0   1  114/11/20  17:39:01  張天成  全球財務部 資深協理     (02)6629-9999
# 1   1  114/11/20  17:39:42  陳君煒       財務部協理       02-25989890
# 2   2  114/11/20  17:41:35  陳君煒       財務部協理       02-25989890
# 3   2  114/11/20  17:43:56  陳正澔       管理部經理  (07)6963037-1290
# 4   1  114/11/20  17:53:21  張家麒  資深副總經理暨財務長          66351880
#
#                                            主旨 符合條款      事實發生日  \
# 0  本公司受邀參加由Citi舉辦之"Citi Taiwan Corporate Day"   12  114/11/24
# 1                                 公告本公司處分有價證券   20  114/11/20
# 2                                 公告本公司處分有價證券   20  114/11/20
# 3                            公告本公司召開法人說明會相關資訊   12  114/11/27
# 4                        公告取得台灣固網(股)公司一筆使用權資產   20  114/11/20
#
#                                                   說明
# 0  符合條款第四條第XX款：12\r\n事實發生日：114/11/24\r\n1.召開法人說明會...
# 1  1.證券名稱:\r\n台積電 普通股\r\n2.交易日期:114/10/27~114/11/...
# 2  1.證券名稱:\r\n順達科 普通股\r\n2.交易日期:114/11/12~114/11/...
# 3  符合條款第四條第XX款：12\r\n事實發生日：114/11/27\r\n1.召開法人說明會...
# 4  1.標的物之名稱及性質（如坐落台中市北區ＸＸ段ＸＸ小段土地）:\r\n台北市內湖區瑞光路4*...
