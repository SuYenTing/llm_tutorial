# %%
import time
import random
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import ActionChains

# %%
# === Chrome 設定 ===
chrome_options = Options()
chrome_options.add_argument("--disable-blink-features=AutomationControlled")  # 移除自動化控制標記
# chrome_options.add_argument("start-maximized")  # 全螢幕
chrome_options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36")

driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.google.com")

time.sleep(random.uniform(1.5, 3.0))  # 隨機等待 像真人

# %%
# === 模擬滑鼠移動 ===
actions = ActionChains(driver)
actions.move_by_offset(20, 20).perform()
time.sleep(random.uniform(0.3, 0.8))

# %%
# find_element: By.ID用法
# === 找搜尋框 ===
search_box = driver.find_element(By.ID, "APjFqb")

# === 模擬真人打字 ===
query = "Selenium Python 模擬真人瀏覽器"
for char in query:
    search_box.send_keys(char)
    time.sleep(random.uniform(0.1, 0.25))  # 每個字元間隔不同

# %%
# find_element: By.NAME用法
# === 找搜尋框 ===
search_box = driver.find_element(By.NAME, "q")

# === 模擬真人打字 ===
query = "Selenium Python 模擬真人瀏覽器"
for char in query:
    search_box.send_keys(char)
    time.sleep(random.uniform(0.1, 0.25))  # 每個字元間隔不同

# %%
# find_element: By.CLASS_NAME用法
# === 找搜尋框 ===
search_box = driver.find_element(By.CLASS_NAME, "gLFyf")

# === 模擬真人打字 ===
query = "Selenium Python 模擬真人瀏覽器"
for char in query:
    search_box.send_keys(char)
    time.sleep(random.uniform(0.1, 0.25))  # 每個字元間隔不同

# %%
# find_element: By.TAG_NAME用法
# === 找搜尋框 ===
search_box = driver.find_element(By.TAG_NAME, "textarea")

# === 模擬真人打字 ===
query = "Selenium Python 模擬真人瀏覽器"
for char in query:
    search_box.send_keys(char)
    time.sleep(random.uniform(0.1, 0.25))  # 每個字元間隔不同

# %%
# find_element: By.CSS_SELECTOR用法
# === 找搜尋框 ===
search_box = driver.find_element(By.CSS_SELECTOR, "#APjFqb")

# === 模擬真人打字 ===
query = "Selenium Python 模擬真人瀏覽器"
for char in query:
    search_box.send_keys(char)
    time.sleep(random.uniform(0.1, 0.25))  # 每個字元間隔不同

# %%
# find_element: By.XPATH用法
# === 找搜尋框 ===
search_box = driver.find_element(By.XPATH, '//*[@id="APjFqb"]')

# === 模擬真人打字 ===
query = "Selenium Python 模擬真人瀏覽器"
for char in query:
    search_box.send_keys(char)
    time.sleep(random.uniform(0.1, 0.25))  # 每個字元間隔不同

# %%
# 清空輸入框
# search_box.clear()

# %%
# 按 Enter
search_box.send_keys(Keys.RETURN)

# %%
# 等待搜尋結果載入
time.sleep(random.uniform(2, 3))

# %%
# 取得搜尋結果連結
results = driver.find_elements(By.CLASS_NAME, "zReHs")
for res in results:
    title = res.find_elements(By.TAG_NAME, "h3")[0].text
    link = res.get_attribute("href")
    print(title)
    print(link)
    print('-'*30)
# Out:
# Selenium 函式庫- Python 網路爬蟲教學 - STEAM 教育學習網
# https://steam.oxxostudio.tw/category/python/spider/selenium.html
# ------------------------------
# Selenium 教學：5 分鐘學會基本自動化操作,快速掌握核心指令
# https://www.pcschool.com.tw/blog/it/selenium-learning
# ------------------------------
# ( Day 27.1 ) Python Selenium 函式庫 - iT 邦幫忙
# https://ithelp.ithome.com.tw/m/articles/10329152
# ------------------------------
# 🪄 魔法比喻：Selenium 就像「網頁小機器人🤖」 你可以把 ...
# https://www.threads.com/@lifefriend_bigcatpanda/post/DHgvCCooImN
# ------------------------------
# 用Python控制Chrome瀏覽器— Selenium初體驗
# https://medium.com/seaniap/%E7%94%A8python%E6%8E%A7%E5%88%B6chrome%E7%80%8F%E8%A6%BD%E5%99%A8-selenium%E5%88%9D%E9%AB%94%E9%A9%97-732929668ce3
# ------------------------------
# [Python爬蟲] Selenium模組
# https://utrustcorp.com/python-selenium/?srsltid=AfmBOorNiCw3ujNpeCewiuR9LrYkw_-Bf_xvPVM7GzTKKP0tOLojj6lX
# ------------------------------
# 【筆記】Selenium 實作：讓你的網頁自動幫你開啟網站
# https://vocus.cc/article/64bbe20efd89780001072d83
# ...

# %%
# 點選下一頁
next_page_btn = driver.find_element(By.ID, "pnnext")
next_page_btn.click()

# %%
# 關閉瀏覽器
driver.quit()
